# %%
import xarray as xr
import numpy as np
import pandas as pd
from datetime import date

# %%
df = pd.read_csv('/home/mohammad/Dossier_travail/Raven/meteodata.csv',parse_dates = ['time'])
#df ['station'] = df['station']-1
#df = df.loc[df['station'] == 1]

ds = df.set_index(['station','time']).to_xarray()

lon = np.array([-70.5, -70.5, -70.7])
lat = np.array([46.4, 46.2, 46.2])
alt = np.array([511, 282, 168])

ds = ds.assign_coords(lon = lon)
ds = ds.assign_coords(lat = lat)
ds = ds.assign_coords(alt = alt)
ds['lon'].attrs = {"standard_name": "longitude",'long_name':'longitude','units':'degrees_east',"axis": "X"}
ds['lat'].attrs = {"standard_name": "latitude",'long_name':'latitude','units':'degrees_north',"axis": "Y"}
ds['alt'].attrs = {"standard_name": "surface_altitude",'long_name':'altitude','units':'m',"axis": "Z"}
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (station: 3, time: 7670, lon: 3, lat: 3, alt: 3)
# Coordinates:
#   * station  (station) int64 1 2 3
#   * time     (time) datetime64[ns] 1998-01-01 1998-01-02 ... 2018-12-31
#   * lon      (lon) float64 -70.5 -70.5 -70.7
#   * lat      (lat) float64 46.4 46.2 46.2
#   * alt      (alt) int64 511 282 168
# Data variables:
#     tasmax   (station, time) float64 -8.5 0.0 3.0 -7.0 -5.0 ... 5.1 3.0 -8.1 0.2
#     tasmin   (station, time) float64 -28.0 -21.0 -5.0 ... -10.9 -18.6 -13.5
#     pr       (station, time) float64 2.0 0.0 1.6 2.2 11.4 ... 11.6 0.0 0.0 11.0

# %%
df2 = pd.read_csv('/home/mohammad/Dossier_travail/Raven/Qobs.csv',parse_dates = ['time'])
ds2 = df2.set_index(['time','station_id']).to_xarray()
ds2
#df_merged.isnull().values.any()
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 7670, station_id: 1)
# Coordinates:
#   * time        (time) datetime64[ns] 1998-01-01 1998-01-02 ... 2018-12-31
#   * station_id  (station_id) int64 23422
# Data variables:
#     qobs        (time, station_id) float64 1.631 1.776 1.996 ... 15.88 16.83

# %%
ds_merged = xr.merge([ds, ds2])
ds_merged
#ds_merged.drop_vars('station_id')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10618/3745164202.py in <module>
# ----> 1 ds_merged = xr.merge([ds, ds2])
#       2 ds_merged
#       3 #ds_merged.drop_vars('station_id')
#
# NameError: name 'ds2' is not defined

# %%
#AA = xr.open_dataset("/home/mohammad/ravenpy/test_hbvecmod_MOhammad/famine_input.nc")
#AA
# Out:
# <xarray.Dataset>
# Dimensions:  (station: 3, time: 7670, lat: 3, lon: 3, alt: 3)
# Coordinates:
#   * time     (time) datetime64[ns] 1998-01-01 1998-01-02 ... 2018-12-31
#   * station  (station) int64 0 1 2
#   * lat      (lat) float64 46.4 46.2 46.2
#   * lon      (lon) float64 -70.5 -70.5 -70.7
#   * alt      (alt) int64 511 282 168
# Data variables:
#     tasmax   (station, time) float64 ...
#     tasmin   (station, time) float64 ...
#     pr       (station, time) float64 ...
#     obs      (time) float64 ...

# %%
ds_merged.to_netcdf("~/ravenpy/test_hbvecmod_MOhammad/famine_input9.nc")

# %%
ds2 = xr.open_dataset("/home/mohammad/Dossier_travail/Raven/famine_input4.nc")
ds2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/.local/lib/python3.8/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/mohammad/Dossier_travail/Raven/famine_input4.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ...

# %%
start_date = date(1998,1,1)
end_date = date(2018,12,31)
n_days = ((end_date - start_date).days)
STATIONS = [
    ("st-germaine", (46.4, -70.5, 511)),
    ("st-prosper", (46.2, -70.5, 282)),
    ("st-georges", (46.2, -70.7, 168)),
]

n_stations = len(STATIONS)

# %%
# Out:
# 7669

# %%
time=pd.date_range(start_date, end_date),

ds = xr.Dataset(
    data_vars=dict(
        tasmax=(["station", "time"], np.asarray(df['tasmax']).reshape(n_stations, n_days)),
        tasmin=(["station", "time"], np.asarray(df['tasmin']).reshape(n_stations, n_days)),
        pr=(["station", "time"], np.asarray(df['pr']).reshape(n_stations, n_days)),
        qobs=("time", qobs),
    ),
    coords=dict(
        time=pd.date_range(start_date, periods=n_days),
        station=range(n_stations),
        lat=(
            "lat",
            lat,
            {
                "standard_name": "latitude",
                "long_name": "latitude",
                "units": "degrees_north",
                "axis": "Y",
            },
        ),
        lon=(
            "lon",
            lon,
            {
                "standard_name": "longitude",
                "long_name": "longitude",
                "units": "degrees_east",
                "axis": "X",
            },
        ),
        alt=(
            "alt",
            alt,
            {
                "standard_name": "surface_altitude",
                "long_name": "altitude",
                "units": "m",
                "axis": "Z",
            },
        ),
        # Add station_name coordinate
    ),
)

ds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_388213/221846514.py in <module>
#       3 ds = xr.Dataset(
#       4     data_vars=dict(
# ----> 5         tasmax=(["station", "time"], np.asarray(df['tasmax']).reshape(n_stations, n_days)),
#       6         tasmin=(["station", "time"], np.asarray(df['tasmin']).reshape(n_stations, n_days)),
#       7         pr=(["station", "time"], np.asarray(df['pr']).reshape(n_stations, n_days)),
#
# ValueError: cannot reshape array of size 23010 into shape (3,7669)

# %%
7669*3
# Out:
# 23007
